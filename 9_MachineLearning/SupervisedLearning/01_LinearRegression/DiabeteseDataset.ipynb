# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.linear_model import LinearRegression

# %%
data_train = np.genfromtxt("train.csv", delimiter=",")

# %%
x = pd.read_csv("train.csv")
y = x["Y"]
x.drop("Y", axis = 1, inplace = True)
x
# Out:
#         # age       sex       bmi        bp        s1        s2        s3  \
# 0   -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1   -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2    0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3    0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.012648 -0.044642 -0.020218 -0.015999  0.012191  0.021233 -0.076536
# 327  0.019913 -0.044642 -0.057941 -0.057314 -0.001569 -0.012587  0.074412
# 328  0.023546 -0.044642  0.070319  0.025315 -0.034592 -0.014466 -0.032356
# 329  0.016281  0.050680  0.072474  0.076958 -0.008449  0.005575 -0.006584
# 330 -0.009147  0.050680 -0.030996 -0.026328 -0.011201 -0.001001 -0.021311
#
#            s4        s5        s6
# 0    0.034309  0.028017  0.011349
# ...

# %%
y
# Out:
# 0      346.0
# 1      104.0
# 2       49.0
# 3      180.0
# 4      110.0
#        ...
# 326    233.0
# 327     63.0
# 328    288.0
# 329    131.0
# 330     42.0
# Name: Y, Length: 331, dtype: float64

# %%
data_test = np.genfromtxt("test.csv", delimiter=",")

# %%
x_test_original = pd.read_csv("test.csv")
x_test.columns = ["# age", "sex", "bmi","bp", "s1", "s2", "s3", "s4", "s5", "s6"]
x_test
# Out:
#         # age       sex       bmi        bp        s1        s2        s3  \
# 0   -0.078165 -0.044642 -0.073030 -0.057314 -0.084126 -0.074277 -0.024993
# 1   -0.030942  0.050680  0.001339 -0.005671  0.064477  0.049416 -0.047082
# 2   -0.005515  0.050680  0.001339 -0.084857 -0.011201 -0.016658  0.048640
# 3   -0.020045 -0.044642 -0.084886 -0.026328 -0.035968 -0.034194  0.041277
# 4   -0.034575 -0.044642 -0.037463 -0.060757  0.020446  0.043466 -0.013948
# ..        ...       ...       ...       ...       ...       ...       ...
# 105  0.009016  0.050680  0.069241  0.059744  0.017694 -0.023234 -0.047082
# 106  0.005383 -0.044642  0.049840  0.097616 -0.015328 -0.016345 -0.006584
# 107  0.009016 -0.044642 -0.012673  0.028758 -0.018080 -0.005072 -0.047082
# 108  0.019913 -0.044642 -0.034229  0.055153  0.067229  0.074155 -0.006584
# 109  0.016281  0.050680  0.009961 -0.043542 -0.096510 -0.094632 -0.039719
#
#            s4        s5        s6
# 0   -0.039493 -0.018118 -0.083920
# ...

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y)

# %%
algo1 = LinearRegression()

# %%
algo1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
score_test = algo1.score(x_test, y_test)
score_train = algo1.score(x_train, y_train)
print(score_train, score_test)
# Out:
# 0.4701708872182382 0.5206840004535511

# %%
y_pred = algo1.predict(x)
y_pred
# Out:
# array([247.36138665,  66.0409736 , 101.30952737, 213.35597083,
#        159.7877695 ,  76.03995096, 168.70981941, 173.3951761 ,
#         52.56615012, 225.97509583, 104.77348896,  89.3516685 ,
#        126.58347622,  63.82610145, 149.9520369 , 142.09130754,
#         68.61905253, 103.78005601, 193.3648407 , 103.81280602,
#        125.72808221, 159.92936437,  93.36835903,  79.29295543,
#         76.15428837, 155.44644607, 188.84864549, 127.25849013,
#        233.51350051, 145.20264201,  55.58071504, 168.45837923,
#        101.70809062, 119.7952723 , 149.94640827, 228.67271302,
#        183.37800681,  91.50169205, 160.46180787, 204.81239598,
#        161.5230006 , 135.2159495 ,  37.96897561, 109.07586272,
#        128.83030848, 212.14323782, 231.98194249, 137.19414352,
#        174.37258639,  82.55340794, 150.81753095,  83.6936816 ,
#        197.03909058, 148.74683369, 162.48855915, 139.12554984,
#        171.34721959, 153.78597887, 211.69073068, 108.06882282,
# ...

# %%
y_pred = pd.DataFrame(y_pred)

# %%
y_pred.to_csv("predicted_value.csv")
